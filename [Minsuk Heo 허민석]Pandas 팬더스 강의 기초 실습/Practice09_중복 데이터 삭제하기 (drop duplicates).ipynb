# %%
import pandas as pd

# %% [markdown]
# ## How to remove duplicate row in dataframe

# %%
student_list = [{'name': 'John', 'major': "Computer Science", 'sex': "male"},
                {'name': 'Nate', 'major': "Computer Science", 'sex': "male"},
                {'name': 'Abraham', 'major': "Physics", 'sex': "male"},
                {'name': 'Brian', 'major': "Psychology", 'sex': "male"},
                {'name': 'Janny', 'major': "Economics", 'sex': "female"},
                {'name': 'Yuna', 'major': "Economics", 'sex': "female"},
                {'name': 'Jeniffer', 'major': "Computer Science", 'sex': "female"},
                {'name': 'Edward', 'major': "Computer Science", 'sex': "male"},
                {'name': 'Zara', 'major': "Psychology", 'sex': "female"},
                {'name': 'Wendy', 'major': "Economics", 'sex': "female"},
                {'name': 'Sera', 'major': "Psychology", 'sex': "female"},
                {'name': 'John', 'major': "Computer Science", 'sex': "male"},
         ]

# %%
pd.DataFrame(student_list, columns = ['name', 'major', 'sex'])
# Out:
#         name             major     sex
# 0       John  Computer Science    male
# 1       Nate  Computer Science    male
# 2    Abraham           Physics    male
# 3      Brian        Psychology    male
# 4      Janny         Economics  female
# 5       Yuna         Economics  female
# 6   Jeniffer  Computer Science  female
# 7     Edward  Computer Science    male
# 8       Zara        Psychology  female
# 9      Wendy         Economics  female
# 10      Sera        Psychology  female
# 11      John  Computer Science    male

# %%
df = pd.DataFrame(student_list, columns = ['name', 'major', 'sex'])

# %% [markdown]
# ## *.duplicated()

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# dtype: bool

# %% [markdown]
# > 중복된 값의 결과를 True 로 보여줌
# ---

# %% [markdown]
# ## .drop_duplicates()

# %%
df.drop_duplicates()
# Out:
#         name             major     sex
# 0       John  Computer Science    male
# 1       Nate  Computer Science    male
# 2    Abraham           Physics    male
# 3      Brian        Psychology    male
# 4      Janny         Economics  female
# 5       Yuna         Economics  female
# 6   Jeniffer  Computer Science  female
# 7     Edward  Computer Science    male
# 8       Zara        Psychology  female
# 9      Wendy         Economics  female
# 10      Sera        Psychology  female

# %% [markdown]
# >중복된 값을 삭제
# ---

# %%
student_list = [{'name': 'John', 'major': "Computer Science", 'sex': "male"},
                {'name': 'Nate', 'major': "Computer Science", 'sex': "male"},
                {'name': 'Abraham', 'major': "Physics", 'sex': "male"},
                {'name': 'Brian', 'major': "Psychology", 'sex': "male"},
                {'name': 'Janny', 'major': "Economics", 'sex': "female"},
                {'name': 'Yuna', 'major': "Economics", 'sex': "female"},
                {'name': 'Jeniffer', 'major': "Computer Science", 'sex': "female"},
                {'name': 'Edward', 'major': "Computer Science", 'sex': "male"},
                {'name': 'Zara', 'major': "Psychology", 'sex': "female"},
                {'name': 'Wendy', 'major': "Economics", 'sex': "female"},
                {'name': 'Nate', 'major': None, 'sex': "male"},
                {'name': 'John', 'major': "Computer Science", 'sex': None},
         ]

# %%
pd.DataFrame(student_list, columns = ['name', 'major', 'sex'])
# Out:
#         name             major     sex
# 0       John  Computer Science    male
# 1       Nate  Computer Science    male
# 2    Abraham           Physics    male
# 3      Brian        Psychology    male
# 4      Janny         Economics  female
# 5       Yuna         Economics  female
# 6   Jeniffer  Computer Science  female
# 7     Edward  Computer Science    male
# 8       Zara        Psychology  female
# 9      Wendy         Economics  female
# 10      Nate              None    male
# 11      John  Computer Science    None

# %%
df = pd.DataFrame(student_list, columns = ['name', 'major', 'sex'])

# %%
df.duplicated(['name'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# dtype: bool

# %% [markdown]
# >'name'의 값이 중복일 경우 결과를 True 로 보여줌
# ---

# %%
df.drop_duplicates(['name'], keep = 'first')
# Out:
#        name             major     sex
# 0      John  Computer Science    male
# 1      Nate  Computer Science    male
# 2   Abraham           Physics    male
# 3     Brian        Psychology    male
# 4     Janny         Economics  female
# 5      Yuna         Economics  female
# 6  Jeniffer  Computer Science  female
# 7    Edward  Computer Science    male
# 8      Zara        Psychology  female
# 9     Wendy         Economics  female

# %% [markdown]
# >'name'의 값이 중복일 경우 'first' 값을 남겨두고 중복 값 삭제 \
# >마지막 값을 남겨두고 싶을 경우 'last' 입력 \
# >default 'keep' 값 = 'first'
# ---
